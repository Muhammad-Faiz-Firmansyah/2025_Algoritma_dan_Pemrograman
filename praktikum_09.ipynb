# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammad-Faiz-Firmansyah/2025_Algoritma_dan_Pemrograman/blob/main/praktikum_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Praktikum 01 - Menggunakan Modul math

# %%
import math

angka = 16
hasil1 = math.sqrt(angka)
hasil2 = math.pow(2, 5)
print("Akar kuadrat dari", angka, "=", hasil1)
print("2 pangkat 5 =", hasil2)

# %% [markdown]
# ## Praktikum 02 - Menggunakan from ... import ...

# %%
from math import sqrt

angka = 25
hasil = sqrt(angka)
print("Akar kuadrat dari", angka, "=", hasil)

# %% [markdown]
# ## Praktikum 03 - Memberi Alias Modul

# %%
import numpy as np

data = np.array([1, 2, 3])
print("Isi array =", data)

# %% [markdown]
# ## Praktikum 04 - Eksplorasi math, random, dan sys

# %%
import math
import random
import sys

hasil1 = math.sqrt(81)
hasil2 = random.randint(1, 10)
versi = sys.version

print("Akar kuadrat 81 =", hasil1)
print("Angka acak 1-10 =", hasil2)
print("Versi Python =", versi)

# %% [markdown]
# ## Praktikum 05 - Membuat Modul Sendiri

# %%
# File: modulku.py (simulasi modul sendiri)
def halo(nama):
    print(f"Halo, {nama}! Selamat belajar Python di Polines.")

# %%
# File: praktikum09_modul_sendiri.py (menggunakan modul)
# Catatan: Di Google Colab, kita langsung panggil fungsi dari cell sebelumnya

halo("Mahasiswa Polines")

# %% [markdown]
# ## Praktikum 06 - Instalasi Modul dengan pip

# %%
# Catatan: Modul requests sudah terinstall di Google Colab
# Jika di komputer lokal, install dengan: pip install requests

import requests

response = requests.get("https://www.polines.ac.id")
print("Status code:", response.status_code)
